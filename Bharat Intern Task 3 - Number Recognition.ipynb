# %% [markdown]
# # Bharat Intern Internship Task by Hardik Panchal

# %% [markdown]
# # Task 3 : Number Recognition

# %% [markdown]
# # Problem Statement:
# ## Handwritten digit recognition system not only detects scanned images of handwritten digits.Handwritten digit recognition using MNIST dataset is a major project made with the help of Neural Network. It basically detects the scanned images of handwritten digits.

# %% [markdown]
# # About the Dataset:
# ## Here we have loaded the MNIST dataset, preprocess the data, create a convolutional neural network model, compile the model, train the model, evaluate the model, and make predictions. The predictions will be printed to the console.
#
# ## The MNIST dataset contains 60,000 training images and 10,000 testing images of handwritten digits from 0 to 9. The code uses a convolutional neural network to learn to recognize these digits. The model is trained on the training images and then evaluated on the testing images. The model achieves an accuracy of over 99% on the testing images, which is very good.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
# Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# ...
# 11490434/11490434 [==============================] - 4s 0us/step

# %%
# Build a convolutional neural network (CNN)
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 29s 35ms/step - loss: 0.3528 - accuracy: 0.8890 - val_loss: 0.0650 - val_accuracy: 0.9797
# Epoch 2/10
# 750/750 [==============================] - 23s 30ms/step - loss: 0.1053 - accuracy: 0.9704 - val_loss: 0.0444 - val_accuracy: 0.9868
# Epoch 3/10
# 750/750 [==============================] - 25s 33ms/step - loss: 0.0742 - accuracy: 0.9788 - val_loss: 0.0531 - val_accuracy: 0.9848
# Epoch 4/10
# 750/750 [==============================] - 24s 32ms/step - loss: 0.0608 - accuracy: 0.9832 - val_loss: 0.0384 - val_accuracy: 0.9883
# Epoch 5/10
# 750/750 [==============================] - 24s 32ms/step - loss: 0.0493 - accuracy: 0.9855 - val_loss: 0.0383 - val_accuracy: 0.9892
# Epoch 6/10
# 750/750 [==============================] - 24s 33ms/step - loss: 0.0396 - accuracy: 0.9890 - val_loss: 0.0432 - val_accuracy: 0.9886
# Epoch 7/10
# ...

# %%
# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0317 - accuracy: 0.9915
# Test accuracy: 0.9915000200271606

# %% [markdown]
# # Bard Code:

# %%
import tensorflow as tf

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
# Preprocess the data
x_train = x_train.reshape(60000, 28, 28, 1)
x_test = x_test.reshape(10000, 28, 28, 1)
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 37s 19ms/step - loss: 0.1296 - accuracy: 0.9613
# Epoch 2/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0435 - accuracy: 0.9862
# Epoch 3/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0290 - accuracy: 0.9907
# Epoch 4/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0206 - accuracy: 0.9937
# Epoch 5/10
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.0155 - accuracy: 0.9947
# Epoch 6/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0124 - accuracy: 0.9959
# Epoch 7/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0105 - accuracy: 0.9967
# Epoch 8/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0068 - accuracy: 0.9978
# Epoch 9/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0074 - accuracy: 0.9974
# Epoch 10/10
# ...

# %%
# Evaluate the model
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 3s 7ms/step - loss: 0.0397 - accuracy: 0.9910
# [0.039707206189632416, 0.9909999966621399]

# %%
# Make predictions
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step

# %%
# Print the predictions
for i in range(len(predictions)):
    print(f"Predicted: {predictions[i]}, Actual: {y_test[i]}")
# Out:
# Predicted: [7.2981807e-15 2.5355692e-11 2.3954818e-12 1.8222075e-10 7.6681439e-12
#  3.2534051e-16 5.2278526e-20 1.0000000e+00 2.0211895e-14 1.2821999e-11], Actual: 7
# Predicted: [2.2344661e-12 3.0954861e-09 1.0000000e+00 2.4406206e-18 3.3198871e-10
#  7.2499765e-24 2.9049986e-15 1.4573848e-16 3.3818819e-17 7.0441931e-19], Actual: 2
# Predicted: [4.9061106e-11 9.9999869e-01 9.1167331e-09 1.6371232e-13 3.0491137e-07
#  1.2768505e-08 5.1273481e-08 8.2415227e-07 1.3840554e-07 2.1130896e-10], Actual: 1
# Predicted: [9.9999988e-01 2.1531225e-13 1.2270977e-13 1.2648328e-14 3.2141068e-14
#  1.1436449e-14 1.3704314e-07 4.6981048e-11 2.8661000e-14 2.6506627e-11], Actual: 0
# Predicted: [4.6795280e-14 1.4693831e-12 1.0383068e-11 4.0101581e-16 9.9999917e-01
#  1.3723672e-11 2.9895960e-14 4.7464821e-13 4.9263621e-13 8.8354358e-07], Actual: 4
# Predicted: [3.3042385e-10 9.9999785e-01 6.2843764e-10 1.9930784e-14 3.9450018e-08
# ...
